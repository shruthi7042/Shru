# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthi7042/Shru/blob/main/LOGISTIC_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LOGISTIC REGRESSION
#
# Drive link for csv file: https://drive.google.com/file/d/175rhCDkhPRr3tWGq2BT616ZAPUnYd_l5/view?usp=sharing

# %%
import pandas as pd
import numpy as np
from sklearn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/breast_cancer_diagnosis.csv")

# %%
df.head(10)
# Out:
#          id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         21.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
# 8          0.12730           0.19320         0.18590              0.09353
# 9          0.11860           0.23960         0.22730              0.08543
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
# 6  ...         22.88          27.66           153.20      1606.0
# 7  ...         17.06          28.14           110.60       897.0
# 8  ...         15.49          30.73           106.20       739.3
# 9  ...         15.09          40.68            97.65       711.4
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
# 8            0.1703             0.5401           0.5390                0.2060
# 9            0.1853             1.0580           1.1050                0.2210
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
# 6          0.3063                  0.08368
# 7          0.3196                  0.11510
# 8          0.4378                  0.10720
# 9          0.4366                  0.20750
#
# [10 rows x 32 columns]

# %%
df.dropna(inplace=True)
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#checking for null values
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#check the number of examples belonging to each class
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#segregating inputs and outputs
from sklearn.model_selection import train_test_split
X=df.drop('diagnosis',axis = 1)
y=df['diagnosis']

# %%
#split training and testing data
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.3,stratify =y, random_state=2024)

# %%
#Logistic Regression
y_test_hat = Classifier.predict(X_test)
results = pd.DataFrame({'Actual': y_test,'predicians' :y_test})
results.head(10)
# Out:
#     Actual predicians
# 524      B          B
# 182      M          M
# 121      M          M
# 434      B          B
# 90       B          B
# 476      B          B
# 76       B          B
# 259      M          M
# 50       B          B
# 266      B          B

# %%
from sklearn.linear_model import LogisticRegression
Classifier=LogisticRegression(solver='liblinear')
Classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
#check accuracy on training data
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_hat))
# Out:
# 0.3742690058479532

# %%
#check accuracy on testing data
y_train_hat=Classifier.predict(X_train)
print(accuracy_score(y_train,y_train_hat))
# Out:
# 0.3793969849246231

# %%
#getting probability predictions from the model
y_test_hat_prob=Classifier.predict_proba(X_test)
print(y_test_hat_prob.shape)
# Out:
# (171, 2)

# %%
#compare the predicted values with the actual values along with the predicted
pls=y_test_hat_prob[:,1]
Results=pd.DataFrame({'Actual':y_test,'Predictions':'y_test_hat','Prob(Class=M)':pls})
Results.head(5)
# Out:
#     Actual Predictions  Prob(Class=M)
# 524      B  y_test_hat       0.532575
# 182      M  y_test_hat       0.611024
# 121      M  y_test_hat       0.636388
# 434      B  y_test_hat       0.569223
# 90       B  y_test_hat       0.571400
